# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
import csv
import time

# %%
url = 'https://www.basenotes.net/fragrancedirectory/?launch1=2021&launch=1&p='
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
# time.sleep(5)
td_list = soup.select('td[style="padding-top: 0px;"] a')

for i in td_list:
    link = i['href']
    new_response = requests.get(link,headers=headers)
    new_soup = BeautifulSoup(new_response.text,'html.parser')
    f_list = new_soup.select('.fragranceheading span')
    p_list = new_soup.select('.peoplelist tr td')
    n_list = new_soup.select('div[class="notespyramid notespyramidb"]')
    r_list = new_soup.select('div.reviewmain > div.reviewblurb')

    product = f_list[0].text
    year = p_list[1].text
    gender = p_list[4].text
    brand = p_list[12].text

    print('Product Name :', product)
    print('Year of Launch :', year)
    print('Gender :', gender)
    print('Brand :', brand)
    for n in n_list:
        print('notes :', n.text)
    for r in r_list:
        print('Review :', r.text)
        print('-'*60)
    print('*'*60)
# Out:
# Product Name : Act
# Year of Launch : 2021
# Gender : Shared / Unisex
# Brand : Der Duft
# notes : Lime, Bitter orange, Star fruit, Vetiver, Ambergris, Cypress, Musk, Tobacco, Moss, Lavender
# ************************************************************
# Product Name : Age of Aquarius
# Year of Launch : 2021
# Gender : Shared / Unisex
# Brand : Alkemia Apothecary and Perfumery
# notes : Mountain mint, Coriander, Blue lavender, Dark aged patchouli
# ************************************************************
# Product Name : Al-Arabiya Extrait de Parfum
# Year of Launch : 2021
# Gender : Shared / Unisex
# Brand : Agar Aura
# notes : Oud, Woods, Resins, Spices
# ************************************************************
# Product Name : Alphaora 30
# Year of Launch : 2021
# Gender : Shared / Unisex
# Brand : Parfumerie Generale
# notes : Blood orange, Albizia blossom, Hinoki sap, Assam moss
# ************************************************************
# ...

# %%
# url = 'https://www.basenotes.net/ID26162936.html'
# headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
# response = requests.get(url, headers=headers)
# soup = BeautifulSoup(response.text, 'html.parser')
# # time.sleep(5)
# f_list = soup.select('.fragranceheading span')
# p_list = soup.select('.peoplelist tr td')
# n_list = soup.select('div[class="notespyramid notespyramidb"]')
# r_list = soup.select('div.reviewmain > div.reviewblurb')
# # print(c_list)
# product = f_list[0].text
# year = p_list[1].text
# gender = p_list[4].text
# rating = p_list[8].select('meta')[0]
# brand = p_list[12].text

# # print('Product Name :', product)
# # print('Year of Launch :', year)
# # print('Gender :', gender)
# # print('Brand :', brand)
# # for n in n_list:
# #     print('notes :', n.text)
# # for r in r_list:
# #     print('Review :', r.text)
# #     print('-'*60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-86737036e9a7> in <module>
#      24 #     print('Review :', r.text)
#      25 #     print('-'*60)
# ---> 26 td_list = soup.select('td[style="padding-top: 0px;"] a')['href']
#      27 print(td_list)
#
# TypeError: list indices must be integers or slices, not str
