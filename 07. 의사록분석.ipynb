# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
url='http://www.bok.or.kr/portal/bbs/B0000245/list.do?menuNo=200761&pageIndex=1'
response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")
result=soup.find_all('span',class_='titlesub')
result[0].text
# Out:
# '금융통화위원회 의사록(2020년도 제27차)(2020.12.24)'

# %%
num=1
title_list=[]
while num<=33:
    url='http://www.bok.or.kr/portal/bbs/B0000245/list.do?menuNo=200761&pageIndex={}'.format(num)
    response=requests.get(url)
    soup=BeautifulSoup(response.text,"html.parser")
    result=soup.find_all('span',class_='titlesub')
    for i in result:
        title_list.append(i.text)
    num=num+1
    print('다운')
print(title_list)
# Out:
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# ['금융통화위원회 의사록(2020년도 제27차)(2020.12.24)', '금융통화위원회 의사록(2020년도 제26차)(2020.12.10)', '금융통화위원회 의사록(2020년도 제25차)(2020.11.26)', '금융통화위원회 의사록(2020년도 제23차)(2020.10.29)', '금융통화위원회 의사록(2020년도 제22차)(2020.10.14) ', '금융통화위원회 의사록(2020년도 제21차)(2020.09.24) ', '금융통화위원회 의사록(2020년도 제20차)(2020.09.10)', '금융통화위원회 의사록(2020년도 제19차)(2020.8.27.)', '금융통화위원회 의사록(2020년도 제17차)(2020.7.30.)', '금융통화위원회 의사록(2020년도 제16차)(2020.7.17.)', '금융통화위원회 의사록(2020년도 제15차)(2020.7.16.)', '금융통화위원회 의사록(2020년도 제14차)(2020.6.24.)', '금융통화위원회 의사록(2020년도 제13차)(2020.6.11.)', '금융통화위원회 의사록(2020년도 제12차)(2020.5.28.)', '금융통화위원회 의사록(2020년도 제11차)(2020.5.14.)', '금융통화위원회 의사록(2020년도 제9차)(2020.4.16.)', '금융통화위원회 의사록(2020년도 제8차)(2020.4.9.)', '금융통화위원회 의사록(2020년도 제7차)(2020.3.26.)', '금융통화위원회 의사록(2020년도 제6차)(2020.3.16.)', '금융통화위원회 의사록(2020년도 제5차)(2020.3.12.)', '금융통화위원회 의사록(2020년도 제4차)(2020.2.27.)', '금융통화위원회 의사록(2020년도 제1차)(2020.1.17.)', '금융통화위원회 의사록(2019년도 제24차)(2019.12.26.)', '금융통화위원회 의사록(2019년도 제23차)(2019.12.12.)', '금융통화위원회 의사록(2019년도 제22차)(2019.11.29.)', '금융통화위원회 의사록(2019년도 제19차)(2019.10.16.)', '금융통화위원회 의사록(2019년도 제18차)(2019.9.26.)', '금융통화위원회 의사록(2019년도 제16차)(2019.8.30.)', '금융통화위원회 의사록(2019년도 제15차)(2019.8.8.)', '금융통화위원회 의사록(2019년도 제13차)(2019.7.18.)', '금융통화위원회 의사록(2019년도 제12차)(2019.6.20.)', '금융통화위원회 의사록(2019년도 제10차)(2019.5.31.)', '금융통화위원회 의사록(2019년도 제9차)(2019.5.9)', '금융통화위원회 의사록(2019년도 제7차)(2019.4.18.)', '금융통화위원회 의사록(2019년도 제6차)(2019.3.28.)', '금융통화위원회 의사록(2019년도 제4차)(2019.2.28.)', '금융통화위원회 의사록(2019년도 제3차)(2019.2.14.)', '금융통화위원회 의사록(2019년도 제2차)(2019.1.24.)', '금융통화위원회 의사록(2019년도 제1차)(2019.1.17.)', '금융통화위원회 의사록(2018년도 제25차)(2018.12.26.) ', '금융통화위원회 의사록(2018년도 제24차)(2018.12.20.) ', '금융통화위원회 의사록(2018년도 제23차)(2018.12.6.)', '금융통화위원회 의사록(2018년도 제22차)(2018.11.30.)', '금융통화위원회 의사록(2018년도 제21차)(2018.11.8.) ', '금융통화위원회 의사록(2018년도 제19차)(2018.10.18.)', '금융통화위원회 의사록(2018년도 제18차)(2018.9.20.) ', '금융통화위원회 의사록(2018년도 제16차)(2018.8.31.) ', '금융통화위원회 의사록(2018년도 제14차)(2018.7.26.) ', '금융통화위원회 의사록(2018년도 제13차)(2018.7.12.) ', '금융통화위원회 의사록(2018년도 제12차)(2018.6.20.) ', '금융통화위원회 의사록(2018년도 제10차)(2018.5.24.) ', '금융통화위원회 의사록(2018년도 제8차)(2018.4.26.)', '금융통화위원회 의사록(2018년도 제7차)(2018.4.12.)', '금융통화위원회 의사록(2018년도 제6차)(2018.3.29.)', '금융통화위원회 의사록(2018년도 제5차)(2018.3.8.)', '금융통화위원회 의사록(2018년도 제4차)(2018.2.27.)', '금융통화위원회 의사록(2018년도 제3차)(2018.2.8.)', '금융통화위원회 의사록(2018년도 제1차)(2018.1.18.)', '금융통화위원회 의사록(2017년도 제25차)(2017.12.28.)', '금융통화위원회 의사록(2017년도 제24차)(2017.12.14.)', '금융통화위원회 의사록(2017년도 제23차)(2017.12.7.)', '금융통화위원회 의사록(2017년도 제22차)(2017.11.30.)', '금융통화위원회 의사록(2017년도 제21차)(2017.11.9.)', '금융통화위원회 의사록(2017년도 제19차)(2017.10.19.)', '금융통화위원회 의사록(2017년도 제18차)(2017.9.21.)', '금융통화위원회 의사록(2017년도 제16차)(2017.8.31.)', '금융통화위원회 의사록(2017년도 제15차)(2017.8.10.)', '금융통화위원회 의사록(2017년도 제13차)(2017.7.13.)', '금융통화위원회 의사록(2017년도 제12차)(2017.6.22.)', '금융통화위원회 의사록(2017년도 제10차)(2017.5.25.)', '금융통화위원회 의사록(2017년도 제8차)(2017.4.27.)', '금융통화위원회 의사록(2017년도 제7차)(2017.4.13.)', '금융통화위원회 의사록(2017년도 제6차)(2017.3.23.)', '금융통화위원회 의사록(2017년도 제4차)(2017.2.23.)', '금융통화위원회 의사록(2017년도 제2차)(2017.1.26.)', '금융통화위원회 의사록(2017년도 제1차)(2017.1.13.)', '금융통화위원회 의사록(2016년도 제26차)(2016.12.29.)', '금융통화위원회 의사록(2016년도 제25차)(2016.12.21.)', '금융통화위원회 의사록(2016년도 제24차)(2016.12.15.)', '금융통화위원회 의사록(2016년도 제23차)(2016.11.24.)', '금융통화위원회 의사록(2016년도 제22차)(2016.11.11.)', '금융통화위원회 의사록(2016년도 제21차)(2016.10.27.)', '금융통화위원회 의사록(2016년도 제20차)(2016.10.13.)', '금융통화위원회 의사록(2016년도 제19차)(2016.9.22.)', '금융통화위원회 의사록(2016년도 제18차)(2016.9.9.)', '금융통화위원회 의사록(2016년도 제16차)(2016.8.11.)', '금융통화위원회 의사록(2016년도 제14차)(2016.7.14.)', '금융통화위원회 의사록(2016년도 제13차)(2016.7.1.)', '금융통화위원회 의사록(2016년도 제12차)(2016.6.23.)', '금융통화위원회 의사록(2016년도 제11차)(2016.6.9.)', '금융통화위원회 의사록(2016년도 제9차)(2016.5.13.)', '금융통화위원회 의사록(2016년도 제7차)(2016.4.19.)', '금융통화위원회 의사록(2016년도 제6차)(2016.3.24.)', '금융통화위원회 의사록(2016년도 제5차)(2016.3.10.)', '금융통화위원회 의사록(2016년도 제4차)(2016.2.25.)', '금융통화위원회 의사록(2016년도 제3차)(2016.2.16)', '금융통화위원회 의사록(2016년도 제2차)(2016.1.28.)', '금융통화위원회 의사록(2016년도 제1차)(2016.1.14.)', '금융통화위원회 의사록(2015년도 제25차)(2015.12.24.)', '금융통화위원회 의사록(2015년도 제24차)(2015.12.16.)', '금융통화위원회 의사록 ...

# %%
len(title_list)
# Out:
# 330

# %%
del title_list[328:]

# %%
print(title_list)
# Out:
# ['금융통화위원회 의사록(2020년도 제27차)(2020.12.24)', '금융통화위원회 의사록(2020년도 제26차)(2020.12.10)', '금융통화위원회 의사록(2020년도 제25차)(2020.11.26)', '금융통화위원회 의사록(2020년도 제23차)(2020.10.29)', '금융통화위원회 의사록(2020년도 제22차)(2020.10.14) ', '금융통화위원회 의사록(2020년도 제21차)(2020.09.24) ', '금융통화위원회 의사록(2020년도 제20차)(2020.09.10)', '금융통화위원회 의사록(2020년도 제19차)(2020.8.27.)', '금융통화위원회 의사록(2020년도 제17차)(2020.7.30.)', '금융통화위원회 의사록(2020년도 제16차)(2020.7.17.)', '금융통화위원회 의사록(2020년도 제15차)(2020.7.16.)', '금융통화위원회 의사록(2020년도 제14차)(2020.6.24.)', '금융통화위원회 의사록(2020년도 제13차)(2020.6.11.)', '금융통화위원회 의사록(2020년도 제12차)(2020.5.28.)', '금융통화위원회 의사록(2020년도 제11차)(2020.5.14.)', '금융통화위원회 의사록(2020년도 제9차)(2020.4.16.)', '금융통화위원회 의사록(2020년도 제8차)(2020.4.9.)', '금융통화위원회 의사록(2020년도 제7차)(2020.3.26.)', '금융통화위원회 의사록(2020년도 제6차)(2020.3.16.)', '금융통화위원회 의사록(2020년도 제5차)(2020.3.12.)', '금융통화위원회 의사록(2020년도 제4차)(2020.2.27.)', '금융통화위원회 의사록(2020년도 제1차)(2020.1.17.)', '금융통화위원회 의사록(2019년도 제24차)(2019.12.26.)', '금융통화위원회 의사록(2019년도 제23차)(2019.12.12.)', '금융통화위원회 의사록(2019년도 제22차)(2019.11.29.)', '금융통화위원회 의사록(2019년도 제19차)(2019.10.16.)', '금융통화위원회 의사록(2019년도 제18차)(2019.9.26.)', '금융통화위원회 의사록(2019년도 제16차)(2019.8.30.)', '금융통화위원회 의사록(2019년도 제15차)(2019.8.8.)', '금융통화위원회 의사록(2019년도 제13차)(2019.7.18.)', '금융통화위원회 의사록(2019년도 제12차)(2019.6.20.)', '금융통화위원회 의사록(2019년도 제10차)(2019.5.31.)', '금융통화위원회 의사록(2019년도 제9차)(2019.5.9)', '금융통화위원회 의사록(2019년도 제7차)(2019.4.18.)', '금융통화위원회 의사록(2019년도 제6차)(2019.3.28.)', '금융통화위원회 의사록(2019년도 제4차)(2019.2.28.)', '금융통화위원회 의사록(2019년도 제3차)(2019.2.14.)', '금융통화위원회 의사록(2019년도 제2차)(2019.1.24.)', '금융통화위원회 의사록(2019년도 제1차)(2019.1.17.)', '금융통화위원회 의사록(2018년도 제25차)(2018.12.26.) ', '금융통화위원회 의사록(2018년도 제24차)(2018.12.20.) ', '금융통화위원회 의사록(2018년도 제23차)(2018.12.6.)', '금융통화위원회 의사록(2018년도 제22차)(2018.11.30.)', '금융통화위원회 의사록(2018년도 제21차)(2018.11.8.) ', '금융통화위원회 의사록(2018년도 제19차)(2018.10.18.)', '금융통화위원회 의사록(2018년도 제18차)(2018.9.20.) ', '금융통화위원회 의사록(2018년도 제16차)(2018.8.31.) ', '금융통화위원회 의사록(2018년도 제14차)(2018.7.26.) ', '금융통화위원회 의사록(2018년도 제13차)(2018.7.12.) ', '금융통화위원회 의사록(2018년도 제12차)(2018.6.20.) ', '금융통화위원회 의사록(2018년도 제10차)(2018.5.24.) ', '금융통화위원회 의사록(2018년도 제8차)(2018.4.26.)', '금융통화위원회 의사록(2018년도 제7차)(2018.4.12.)', '금융통화위원회 의사록(2018년도 제6차)(2018.3.29.)', '금융통화위원회 의사록(2018년도 제5차)(2018.3.8.)', '금융통화위원회 의사록(2018년도 제4차)(2018.2.27.)', '금융통화위원회 의사록(2018년도 제3차)(2018.2.8.)', '금융통화위원회 의사록(2018년도 제1차)(2018.1.18.)', '금융통화위원회 의사록(2017년도 제25차)(2017.12.28.)', '금융통화위원회 의사록(2017년도 제24차)(2017.12.14.)', '금융통화위원회 의사록(2017년도 제23차)(2017.12.7.)', '금융통화위원회 의사록(2017년도 제22차)(2017.11.30.)', '금융통화위원회 의사록(2017년도 제21차)(2017.11.9.)', '금융통화위원회 의사록(2017년도 제19차)(2017.10.19.)', '금융통화위원회 의사록(2017년도 제18차)(2017.9.21.)', '금융통화위원회 의사록(2017년도 제16차)(2017.8.31.)', '금융통화위원회 의사록(2017년도 제15차)(2017.8.10.)', '금융통화위원회 의사록(2017년도 제13차)(2017.7.13.)', '금융통화위원회 의사록(2017년도 제12차)(2017.6.22.)', '금융통화위원회 의사록(2017년도 제10차)(2017.5.25.)', '금융통화위원회 의사록(2017년도 제8차)(2017.4.27.)', '금융통화위원회 의사록(2017년도 제7차)(2017.4.13.)', '금융통화위원회 의사록(2017년도 제6차)(2017.3.23.)', '금융통화위원회 의사록(2017년도 제4차)(2017.2.23.)', '금융통화위원회 의사록(2017년도 제2차)(2017.1.26.)', '금융통화위원회 의사록(2017년도 제1차)(2017.1.13.)', '금융통화위원회 의사록(2016년도 제26차)(2016.12.29.)', '금융통화위원회 의사록(2016년도 제25차)(2016.12.21.)', '금융통화위원회 의사록(2016년도 제24차)(2016.12.15.)', '금융통화위원회 의사록(2016년도 제23차)(2016.11.24.)', '금융통화위원회 의사록(2016년도 제22차)(2016.11.11.)', '금융통화위원회 의사록(2016년도 제21차)(2016.10.27.)', '금융통화위원회 의사록(2016년도 제20차)(2016.10.13.)', '금융통화위원회 의사록(2016년도 제19차)(2016.9.22.)', '금융통화위원회 의사록(2016년도 제18차)(2016.9.9.)', '금융통화위원회 의사록(2016년도 제16차)(2016.8.11.)', '금융통화위원회 의사록(2016년도 제14차)(2016.7.14.)', '금융통화위원회 의사록(2016년도 제13차)(2016.7.1.)', '금융통화위원회 의사록(2016년도 제12차)(2016.6.23.)', '금융통화위원회 의사록(2016년도 제11차)(2016.6.9.)', '금융통화위원회 의사록(2016년도 제9차)(2016.5.13.)', '금융통화위원회 의사록(2016년도 제7차)(2016.4.19.)', '금융통화위원회 의사록(2016년도 제6차)(2016.3.24.)', '금융통화위원회 의사록(2016년도 제5차)(2016.3.10.)', '금융통화위원회 의사록(2016년도 제4차)(2016.2.25.)', '금융통화위원회 의사록(2016년도 제3차)(2016.2.16)', '금융통화위원회 의사록(2016년도 제2차)(2016.1.28.)', '금융통화위원회 의사록(2016년도 제1차)(2016.1.14.)', '금융통화위원회 의사록(2015년도 제25차)(2015.12.24.)', '금융통화위원회 의사록(2015년도 제24차)(2015.12.16.)', '금융통화위원회 의사록 ...

# %%
url='http://www.bok.or.kr/portal/bbs/B0000245/list.do?menuNo=200761&pageIndex=1'
response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")
result=soup.find_all('span',class_='date')
s=result[0].text
re.search(r'[0-9]{4}\.[0-9]{2}\.[0-9]{2}',s).group()
# Out:
# '2021.01.08'

# %%
import re
num=1
date_list=[]
while num<=33:
    url='http://www.bok.or.kr/portal/bbs/B0000245/list.do?menuNo=200761&pageIndex={}'.format(num)
    response=requests.get(url)
    soup=BeautifulSoup(response.text,"html.parser")
    result=soup.find_all('span',class_='date')
    for i in result:
        s=i.text
        date_final=re.search(r'[0-9]{4}\.[0-9]{2}\.[0-9]{2}',s).group()
        date_list.append(date_final)
    print('다운')
    num=num+1
print(date_list)
# Out:
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# 다운
# ['2021.01.08', '2020.12.29', '2020.12.15', '2020.11.17', '2020.11.03', '2020.10.08', '2020.09.29', '2020.09.15', '2020.08.18', '2020.08.04', '2020.08.04', '2020.07.10', '2020.06.30', '2020.06.16', '2020.06.02', '2020.05.06', '2020.04.28', '2020.04.14', '2020.03.31', '2020.03.31', '2020.03.17', '2020.02.04', '2020.01.10', '2019.12.31', '2019.12.17', '2019.11.05', '2019.10.11', '2019.09.17', '2019.08.27', '2019.08.06', '2019.07.09', '2019.06.18', '2019.05.28', '2019.05.07', '2019.04.12', '2019.03.19', '2019.03.05', '2019.02.12', '2019.02.07', '2019.01.15', '2019.01.08', '2018.12.26', '2018.12.18', '2018.11.27', '2018.11.06', '2018.10.10', '2018.09.18', '2018.08.14', '2018.07.31', '2018.07.06', '2018.06.12', '2018.05.15', '2018.05.02', '2018.04.17', '2018.03.27', '2018.03.20', '2018.02.27', '2018.02.06', '2018.01.16', '2018.01.02', '2017.12.26', '2017.12.19', '2017.11.28', '2017.11.07', '2017.10.10', '2017.09.19', '2017.08.29', '2017.08.01', '2017.07.07', '2017.06.13', '2017.05.16', '2017.05.02', '2017.04.07', '2017.03.14', '2017.02.14', '2017.01.31', '2017.01.17', '2017.01.10', '2017.01.03', '2016.12.13', '2016.11.29', '2016.11.15', '2016.11.01', '2016.10.11', '2016.09.27', '2016.08.30', '2016.08.02', '2016.07.19', '2016.07.12', '2016.06.28', '2016.05.31', '2016.05.04', '2016.04.12', '2016.03.29', '2016.03.15', '2016.03.02', '2016.02.16', '2016.02.02', '2016.01.12', '2016.01.05', '2015.12.29', '2015.12.15', '2015.12.01', '2015.11.17', '2015.11.03', '2015.10.13', '2015.09.30', '2015.09.15', '2015.09.01', '2015.08.11', '2015.07.28', '2015.07.14', '2015.06.30', '2015.06.02', '2015.05.12', '2015.04.28', '2015.04.14', '2015.03.31', '2015.03.10', '2015.02.17', '2015.02.03', '2015.01.13', '2014.12.30', '2014.12.02', '2014.11.11', '2014.11.04', '2014.10.14', '2014.09.30', '2014.09.02', '2014.08.12', '2014.07.29', '2014.07.01', '2014.05.27', '2014.05.13', '2014.04.29', '2014.04.15', '2014.04.01', '2014.03.04', '2014.01.28', '2014.01.14', '2013.12.31', '2013.12.03', '2013.11.12', '2013.10.29', '2013.10.15', '2013.10.01', '2013.08.27', '2013.08.13', '2013.07.30', '2013.07.16', '2013.07.02', '2013.05.28', '2013.05.14', '2013.04.30', '2013.04.16', '2013.04.02', '2013.03.19', '2013.03.05', '2013.01.29', '2013.01.15', '2013.01.02', '2012.11.27', '2012.11.13', '2012.10.30', '2012.10.16', '2012.10.02', '2012.09.18', '2012.09.11', '2012.08.28', '2012.08.07', '2012.07.24', '2012.06.26', '2012.05.29', '2012.05.08', '2012.04.24', '2012.03.27', '2012.03.13', '2012.02.28', '2012.02.14', '2012.02.07', '2012.01.31', '2012.01.25', '2012.01.13', '2011.12.27', '2011.11.29', '2011.11.08', '2011.10.25', '2011.09.27', '2011.09.06', '2011.08.30', '2011.08.09', '2011.07.26', '2011.06.28', '2011.05.31', '2011.05.11', '2011.04.26', '2011.04.12', '2011.03.29', '2011.03.08', '2011.03.02', '2011.02.22', '2011.02.08', '2011.01.25', '2011.01.04', '2010.11.30', '2010.11.09', '2010.10.26', '2010.10.19', '2010.09.28', '2010.09.14', '2010.08.24', '2010.08.10', '2010.07.27', '2010.06.29', '2010.06.08', '2010.05.25', '2010.05.11', '2010.04.27', '2010.03.30', '2010.03.09', '2010.02.23', '2010.02.23', '2010.02.09', '2010.01.26', '2010.01.12', '2009.12.29', '2009.11.24', '2009.11.10', '2009.10.27', '2009.09.29', '2009.09.08', '2009.08.25', '2009.08.11', '2009.07.28', '2009.07.07', '2009.06.23', '2009.06.16', '2009.06.09', '2009.05.26', '2009.05.12', '2009.04.28', '2009.04.14', '2009.03.31', '2009.03.10', '2009.02.24', '2009.02.17', '2009.02.10', '2009.01.28', '2009.01.20', '2008.12.23', '2008.12.09', '2008.12.09', '2008.11.25', '2008.11.11', '2008.10.28', '2008.09.23', '2008.09.09', '2008.08.26', '2008.08.12', '2008.07.29', '2008.07.08', '2008.06.24', '2008.05.27', '2008.05.06', '2008.04.22', '2008.04.01', '2008.03.11', '2008.02.26', '2008.02.19', '2008.02.05', '2008.01.22', '2008.01.08', '2007.12.26', '2007.11.27', '2007.11.06', '2007.10.23', '2007.09.27', '2007.09.11', '2007.08.28', '2007.08.07', '2007.07.24', '2007.06.26', '2007.05.29', '2007.05.08', '2007.04.24', '2007.03. ...

# %%
print(len(date_list))
# Out:
# 330

# %%
del date_list[328:]

# %%
date_list
# Out:
# ['2021.01.08',
#  '2020.12.29',
#  '2020.12.15',
#  '2020.11.17',
#  '2020.11.03',
#  '2020.10.08',
#  '2020.09.29',
#  '2020.09.15',
#  '2020.08.18',
#  '2020.08.04',
#  '2020.08.04',
#  '2020.07.10',
#  '2020.06.30',
#  '2020.06.16',
#  '2020.06.02',
#  '2020.05.06',
#  '2020.04.28',
#  '2020.04.14',
#  '2020.03.31',
#  '2020.03.31',
#  '2020.03.17',
#  '2020.02.04',
#  '2020.01.10',
#  '2019.12.31',
#  '2019.12.17',
#  '2019.11.05',
#  '2019.10.11',
#  '2019.09.17',
#  '2019.08.27',
#  '2019.08.06',
#  '2019.07.09',
#  '2019.06.18',
#  '2019.05.28',
#  '2019.05.07',
#  '2019.04.12',
#  '2019.03.19',
#  '2019.03.05',
#  '2019.02.12',
#  '2019.02.07',
#  '2019.01.15',
#  '2019.01.08',
#  '2018.12.26',
#  '2018.12.18',
#  '2018.11.27',
#  '2018.11.06',
#  '2018.10.10',
#  '2018.09.18',
#  '2018.08.14',
#  '2018.07.31',
#  '2018.07.06',
#  '2018.06.12',
#  '2018.05.15',
#  '2018.05.02',
#  '2018.04.17',
#  '2018.03.27',
#  '2018.03.20',
#  '2018.02.27',
#  '2018.02.06',
#  '2018.01.16',
#  '2018.01.02',
#  '2017.12.26',
#  '2017.12.19',
#  '2017.11.28',
#  '2017.11.07',
#  '2017.10.10',
#  '2017.09.19',
#  '2017.08.29',
#  '2017.08.01',
#  '2017.07.07',
#  '2017.06.13',
#  '2017.05.16',
#  '2017.05.02',
#  '2017.04.07',
#  '2017.03.14',
#  '2017.02.14',
#  '2017.01.31',
#  '2017.01.17',
#  '2017.01.10',
#  '2017.01.03',
#  '2016.12.13',
#  '2016.11.29',
#  '2016.11.15',
#  '2016.11.01',
#  '2016.10.11',
#  '2016.09.27',
#  '2016.08.30',
#  '2016.08.02',
#  '2016.07.19',
#  '2016.07.12',
#  '2016.06.28',
#  '2016.05.31',
#  '2016.05.04',
#  '2016.04.12',
#  '2016.03.29',
#  '2016.03.15',
#  '2016.03.02',
#  '2016.02.16',
#  '2016.02.02',
#  '2016.01.12',
#  '2016.01.05',
#  '2015.12.29',
#  '2015.12.15',
#  '2015.12.01',
#  '2015.11.17',
#  '2015.11.03',
#  '2015.10.13',
#  '2015.09.30',
#  '2015.09.15',
#  '2015.09.01',
#  '2015.08.11',
#  '2015.07.28',
#  '2015.07.14',
#  '2015.06.30',
#  '2015.06.02',
#  '2015.05.12',
#  '2015.04.28',
#  '2015.04.14',
#  '2015.03.31',
#  '2015.03.10',
#  '2015.02.17',
#  '2015.02.03',
#  '2015.01.13',
#  '2014.12.30',
#  '2014.12.02',
#  '2014.11.11',
#  '2014.11.04',
#  '2014.10.14',
#  '2014.09.30',
#  '2014.09.02',
#  '2014.08.12',
#  '2014.07.29',
#  '2014.07.01',
#  '2014.05.27',
#  '2014.05.13',
#  '2014.04.29',
#  '2014.04.15',
#  '2014.04.01',
#  '2014.03.04',
#  '2014.01.28',
#  '2014.01.14',
#  '2013.12.31',
#  '2013.12.03',
#  '2013.11.12',
#  '2013.10.29',
#  '2013.10.15',
#  '2013.10.01',
#  '2013.08.27',
#  '2013.08.13',
#  '2013.07.30',
#  '2013.07.16',
#  '2013.07.02',
#  '2013.05.28',
#  '2013.05.14',
#  '2013.04.30',
#  '2013.04.16',
#  '2013.04.02',
#  '2013.03.19',
#  '2013.03.05',
#  '2013.01.29',
#  '2013.01.15',
#  '2013.01.02',
#  '2012.11.27',
#  '2012.11.13',
#  '2012.10.30',
#  '2012.10.16',
#  '2012.10.02',
#  '2012.09.18',
#  '2012.09.11',
#  '2012.08.28',
#  '2012.08.07',
#  '2012.07.24',
#  '2012.06.26',
#  '2012.05.29',
#  '2012.05.08',
#  '2012.04.24',
#  '2012.03.27',
#  '2012.03.13',
#  '2012.02.28',
#  '2012.02.14',
#  '2012.02.07',
#  '2012.01.31',
#  '2012.01.25',
#  '2012.01.13',
#  '2011.12.27',
#  '2011.11.29',
#  '2011.11.08',
#  '2011.10.25',
#  '2011.09.27',
#  '2011.09.06',
#  '2011.08.30',
#  '2011.08.09',
#  '2011.07.26',
#  '2011.06.28',
#  '2011.05.31',
#  '2011.05.11',
#  '2011.04.26',
#  '2011.04.12',
#  '2011.03.29',
#  '2011.03.08',
#  '2011.03.02',
#  '2011.02.22',
#  '2011.02.08',
#  '2011.01.25',
#  '2011.01.04',
#  '2010.11.30',
#  '2010.11.09',
#  '2010.10.26',
#  '2010.10.19',
#  '2010.09.28',
#  '2010.09.14',
#  '2010.08.24',
#  '2010.08.10',
#  '2010.07.27',
#  '2010.06.29',
#  '2010.06.08',
#  '2010.05.25',
#  '2010.05.11',
#  '2010.04.27',
#  '2010.03.30',
#  '2010.03.09',
#  '2010.02.23',
#  '2010.02.23',
#  '2010.02.09',
#  '2010.01.26',
#  '2010.01.12',
#  '2009.12.29',
#  '2009.11.24',
#  '2009.11.10',
#  '2009.10.27',
#  '2009.09.29',
#  '2009.09.08',
#  '2009.08.25',
#  '2009.08.11',
#  '2009.07.28',
#  '2009.07.07',
#  '2009.06.23',
#  '2009.06.16',
#  '2009.06.09',
#  '2009.05.26',
#  '2009.05.12',
#  '2009.04.28',
#  '2009.04.14',
#  '2009.03.31',
#  '2009.03.10',
#  '2009.02.24',
#  '2009.02.17',
#  '2009.02.10',
#  '2009.01.28',
#  '2009.01.20',
#  '2008.12.23',
#  '2008.12.09',
#  '2008.12.09',
#  '2008.11.25',
#  '2008.11.11',
#  '2008.10.28',
#  '2008.09.23',
#  '2008.09.09',
#  '2008.08.26',
#  '2008.08.12',
#  '2008.07.29',
#  '2008.07.08',
#  '2008.06.24',
#  '2008.05.27',
#  '2008.05.06',
#  '2008.04.22',
#  '2008.04.01',
#  '2008.03.11',
#  '2008.02.26',
#  '2008.02.19',
#  '2008.02.05',
#  '2008.01.22',
#  '2008.01.08',
#  '2007.12.26',
#  '2007.11.27',
#  '2007.11.06',
#  '2007.10.23',
#  '2007.09.27',
#  '2007.09.11',
#  '2007.08.28',
#  '2007.08.07',
#  '2007.07.24',
#  '2007.06.26',
#  '2007.05.29',
#  '2007.05.08',
#  '2007.04.24',
#  '2007.03.27',
#  '2007.03.13',
#  '2007.02.27',
#  '2007.02.20',
#  '2007.02.06',
#  '2007.01.23',
#  '2007.01.09',
#  '2006.12.26',
#  '2006.12.12',
#  '2006.11.28',
#  '2006.11.07',
#  '2006.10.24',
#  '2006.10.10',
#  '2006.10.04',
#  '2006.09.26',
#  '2006.08.22',
#  '2006.08.08',
#  '2006.07.25',
#  '2006.07.11',
#  '2006.06.27',
#  '2006.05.23',
#  '2006.05.09',
#  '2006.04.25',
#  '2006.03.28',
#  '2006.03.14',
#  '2006.02.28',
#  '2006.02.21',
#  '2006.02.07',
#  '2006.01.24',
#  '2005.12.27',
#  '2005.11.29',
#  '2005.11.08',
#  '2005.10.25',
#  '2005.09.27',
#  '2005.08.23',
#  '2005.08.09',
#  '2005.07.26',
#  '2005.06.28',
#  '2005.05.24',
#  '2005.05.20',
#  '2005.05.13',
#  '2005.05.12',
#  '2005.05.12']

# %%
def tidy_sentences(section):
    sentence_enders = re.compile(r'((?<=[함음됨임봄짐움])(\s*\n|\.|;)|(?<=다)\.)\s*')
    splits = list((m.start(), m.end()) for m in re.finditer(sentence_enders, section))
    starts = [0] + [i[1] for i in splits]
    ends = [i[0] for i in splits]
    sentences = [section[start:end] for start, end in zip(starts[:-1], ends)]
    for i, s in enumerate(sentences):
        sentences[i] = (s.replace('\n', ' ').replace(' ', ' ')) + '.'

    text = '\n'.join(sentences) if len(sentences) > 0 else ''
    return sentences, text

# %%
import re 

def preprocess_minutes(minutes):

    pos = re.search('(.?국내외\s?경제\s?동향.?과 관련하여,?|\(가\).+경제전망.*|\(가\) 국내외 경제동향 및 평가)\n?\s*일부 위원은', minutes, re.MULTILINE)
    s1 = pos.start() if pos else -1
    pos = re.search('(.?외환.?국제금융\s?동향.?과 관련하여.*|\(나\) 외환.국제금융\s?(및 금융시장)?\s?동향)\n?\s*(일부 위원은|대부분의 위원들은)', minutes,re.MULTILINE)
    s2 = pos.start() if pos else -1
    pos = re.search('(.?금융시장\s?동향.?과 관련하여,?|\(다\) 금융시장\s?동향)\n?\s*일부 위원은', minutes, re.MULTILINE)
    s3 = pos.start() if pos else -1
    pos = re.search('((\((다|라)\) )?.?통화정책\s?방향.?에 관한 토론,?|이상과 같은 의견\s?교환을 바탕으로.*통화정책\s?방향.*에.*토론.*)\n?', minutes,re.MULTILINE)
    s4 = pos.start() if pos else -1
    pos = re.search('(\(4\) 정부측 열석자 발언.*)\n?', minutes, re.MULTILINE)
    s5 = pos.start() if pos else -1
    pos = re.search('(\(.*\) 한국은행 기준금리 결정에 관한 위원별 의견\s?개진|이상과 같은 토론에 이어 .* 관한 위원별 의견개진이 있었음.*)\n?', minutes,re.MULTILINE)
    s6 = pos.start() if pos else -1
    positer = re.finditer('(\(\s?.*\s?\) ()(심의결과|토의결론))\n?', minutes, re.MULTILINE)
    s7 = [pos.start() for pos in positer if pos.start() > s6]
    s7 = s7[0] if s7 else -1

    # 국내외 경제동향
    bos = s1
    eos = s2
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section1, section1_txt = tidy_sentences(section)

    # 외환․국제금융 동향
    bos = s2
    eos = s3 if s3 >= 0 else s4
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section2, section2_txt = tidy_sentences(section)
    #print(section)

    # 금융시장 동향
    bos = s3
    eos = s4
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section3, section3_txt = tidy_sentences(section)

    # 통화정책방향
    bos = s4
    eos = s5 if s5 >= 0 else s6 if s6 >= 0 else s7
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section4, section4_txt = tidy_sentences(section)

    # 위원별 의견 개진
    bos = s6
    eos = s7
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section5, section5_txt = tidy_sentences(section)

    # 정부측 열석자 발언
    bos = s5
    eos = s6
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('정부측 열석자 발언', section, re.MULTILINE)
    bos = pos.end() + 1 if pos else -1
    section = section[bos:] if bos >= 0 else section
    section6, section6_txt = tidy_sentences(section)

    sections = ['Economic Situation', 'Foreign Currency', 'Financial Markets',
                'Monetary Policy', 'Participants’ Views', 'Government’s View']
    section_texts = section2 + section3


    return section_texts

# %%
import fitz
import re
filename='C:/jupyter/kdigital_lecture/금통위 pdf/금통위 의사록(1).pdf'
doc=fitz.open(filename)
page_count=doc.pageCount
page=0
content = ""
while (page<page_count):
    p=doc.loadPage(page)
    content += p.getText()    
    page+=1

content
# Out:
# mupdf: cannot open C:/jupyter/kdigital_lecture/금통위 pdf/금통위 의사록(1).pdf: No such file or directory
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-8ec212321544> in <module>
#       2 import re
#       3 filename='C:/jupyter/kdigital_lecture/금통위 pdf/금통위 의사록(1).pdf'
# ----> 4 doc=fitz.open(filename)
#       5 page_count=doc.pageCount
#       6 page=0
#
# ~\anaconda3\lib\site-packages\fitz\fitz.py in __init__(self, filename, stream, filetype, rect, width, height, fontsize)
#    3638         _fitz.Document_swiginit(
#    3639             self,
# -> 3640             _fitz.new_Document(
#    3641                 filename, stream, filetype, rect, width, height, fontsize
#    3642             ),
#
# RuntimeError: cannot open C:/jupyter/kdigital_lecture/금통위 pdf/금통위 의사록(1).pdf: No such file or directory

# %%
import fitz
import re
num=1
content = ""
content_list_final=n[]
while num<=328:
    filename='C:/jupyter/kdigital_lecture/금통위 pdf/금통위 의사록({}).pdf'.format(num)
    doc=fitz.open(filename)
    page_count=doc.pageCount
    page=0
    content = ""
    while (page<page_count):
        p=doc.loadPage(page)
        content += p.getText()
        page+=1    
    num=num+1
    
    total_sentences = preprocess_minutes(content)
    
    content_list_final.append("@@@".join(total_sentences ))
# Out:
#   File "<ipython-input-7-bb129a30d7ee>", line 5
#     content_list_final=n[]
#                          ^
# SyntaxError: invalid syntax

# %%
import fitz
import re
num=1
content_list=[]
content_list_final=[]
while num<=10:
    filename='C:/jupyter/kdigital_lecture/금통위 pdf/금통위 의사록({}).pdf'.format(num)
    doc=fitz.open(filename)
    page_count=doc.pageCount
    page=0
    while (page<page_count):
        p=doc.loadPage(page)
        text=p.getText()
        text_final=text.strip().replace('\n','')
        content_list.append(text_final)
        page+=1
    print('다운 {}개'.format(num))
    num=num+1
    text_sum=' '.join(content_list)
    content_list_final.append(text_sum)
# Out:
# 다운 1개
# 다운 2개
# 다운 3개
# 다운 4개
# 다운 5개
# 다운 6개
# 다운 7개
# 다운 8개
# 다운 9개
# 다운 10개

# %%
print(text_sum)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(content_list_final)
# Out:
# 328

# %%
del date_list[200:]
del content_list_final[200:]
del title_list[200:]

# %%
import pandas as pd
minutes={'title':title_list,'date':date_list,'의사록분석':content_list_final}
minutes=pd.DataFrame(minutes)
minutes.to_csv('의사록분석4.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-70f8edf64239> in <module>
#       1 import pandas as pd
# ----> 2 minutes={'title':title_list,'date':date_list,'의사록분석':content_list_final}
#       3 minutes=pd.DataFrame(minutes)
#       4 minutes.to_csv('의사록분석4.csv')
#
# NameError: name 'content_list_final' is not defined

# %%
minutes
# Out:
#                                      title        date  \
# 0     금융통화위원회 의사록(2020년도 제26차)(2020.12.10)  2020.12.29
# 1     금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
# 2     금융통화위원회 의사록(2020년도 제23차)(2020.10.29)  2020.11.17
# 3    금융통화위원회 의사록(2020년도 제22차)(2020.10.14)   2020.11.03
# 4    금융통화위원회 의사록(2020년도 제21차)(2020.09.24)   2020.10.08
# ..                                     ...         ...
# 323     금융통화위원회 의사록(2005년도 제7차)(2005.3.24)  2005.05.20
# 324     금융통화위원회 의사록(2005년도 제6차)(2005.3.10)  2005.05.13
# 325     금융통화위원회 의사록(2005년도 제2차)(2005.1.13)  2005.05.12
# 326     금융통화위원회 의사록(2005년도 제4차)(2005.2.15)  2005.05.12
# 327      금융통화위원회 의사록(2005년도 제1차)(2005.1.6)  2005.04.15
#
#                                                  의사록분석
# 0
# 1    일부 위원은 최근 국제금융시장에서 금융기 , ｢ ｣ 관간 거래상대방 위험이 증대되면...
# 2
# 3
# 4
# ..                                                 ...
# 323
# 324
# 325
# 326
# 327
#
# [328 rows x 3 columns]

# %%
minutes=minutes.replace('','NaN')
minutes
# Out:
#                                      title        date  \
# 0     금융통화위원회 의사록(2020년도 제26차)(2020.12.10)  2020.12.29
# 1     금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
# 2     금융통화위원회 의사록(2020년도 제23차)(2020.10.29)  2020.11.17
# 3    금융통화위원회 의사록(2020년도 제22차)(2020.10.14)   2020.11.03
# 4    금융통화위원회 의사록(2020년도 제21차)(2020.09.24)   2020.10.08
# ..                                     ...         ...
# 323     금융통화위원회 의사록(2005년도 제7차)(2005.3.24)  2005.05.20
# 324     금융통화위원회 의사록(2005년도 제6차)(2005.3.10)  2005.05.13
# 325     금융통화위원회 의사록(2005년도 제2차)(2005.1.13)  2005.05.12
# 326     금융통화위원회 의사록(2005년도 제4차)(2005.2.15)  2005.05.12
# 327      금융통화위원회 의사록(2005년도 제1차)(2005.1.6)  2005.04.15
#
#                                                  의사록분석
# 0                                                  NaN
# 1    일부 위원은 최근 국제금융시장에서 금융기 , ｢ ｣ 관간 거래상대방 위험이 증대되면...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 323                                                NaN
# 324                                                NaN
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
#
# [328 rows x 3 columns]

# %%
minutes.dropna()
minutes
# Out:
#                                      title        date  \
# 0     금융통화위원회 의사록(2020년도 제26차)(2020.12.10)  2020.12.29
# 1     금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
# 2     금융통화위원회 의사록(2020년도 제23차)(2020.10.29)  2020.11.17
# 3    금융통화위원회 의사록(2020년도 제22차)(2020.10.14)   2020.11.03
# 4    금융통화위원회 의사록(2020년도 제21차)(2020.09.24)   2020.10.08
# ..                                     ...         ...
# 323     금융통화위원회 의사록(2005년도 제7차)(2005.3.24)  2005.05.20
# 324     금융통화위원회 의사록(2005년도 제6차)(2005.3.10)  2005.05.13
# 325     금융통화위원회 의사록(2005년도 제2차)(2005.1.13)  2005.05.12
# 326     금융통화위원회 의사록(2005년도 제4차)(2005.2.15)  2005.05.12
# 327      금융통화위원회 의사록(2005년도 제1차)(2005.1.6)  2005.04.15
#
#                                                  의사록분석
# 0                                                  NaN
# 1    일부 위원은 최근 국제금융시장에서 금융기 , ｢ ｣ 관간 거래상대방 위험이 증대되면...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 323                                                NaN
# 324                                                NaN
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
#
# [328 rows x 3 columns]

# %%
idx=minutes[minutes['의사록분석']=='NaN'].index
minutes=minutes.drop(idx)
minutes
# Out:
#                                      title        date  \
# 1     금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
# 5     금융통화위원회 의사록(2020년도 제20차)(2020.09.10)  2020.09.29
# 20     금융통화위원회 의사록(2020년도 제1차)(2020.1.17.)  2020.02.04
# 21   금융통화위원회 의사록(2019년도 제24차)(2019.12.26.)  2020.01.10
# 23   금융통화위원회 의사록(2019년도 제22차)(2019.11.29.)  2019.12.17
# ..                                     ...         ...
# 307      금융통화위원회 의사록(2006년도 제4차)(2006.2.9)  2006.03.28
# 308     금융통화위원회 의사록(2006년도 제3차)(2006.1.26)  2006.03.14
# 309     금융통화위원회 의사록(2006년도 제2차)(2006.1.12)  2006.02.28
# 314   금융통화위원회 의사록(2005년도 제21차)(2005.10.11)  2005.11.29
# 318     금융통화위원회 의사록(2005년도 제14차)(2005.7.7)  2005.08.23
#
#                                                  의사록분석
# 1    일부 위원은 최근 국제금융시장에서 금융기 , ｢ ｣ 관간 거래상대방 위험이 증대되면...
# 5    일부 위원은 최근 국제금융시장에서 국제신 · ｢ ｣ 용평가사들이 선진국의 국가신용등...
# 20   일부 위원은 외화유동성 사정을 분석 , ｢ ․ ｣ 함에 있어서 유동외채비율이 중요한...
# 21   일부 위원은 2002년부터 거의 예외 없 이 연초에는 원화의 강세 현상이 나타나 왔...
# 23   일부 위원은 자본유입에 대해서는 관대 한 반면 자본유출에 대해서는 비교적 엄격한 경...
# ..                                                 ...
# 307  일부 위원은 일본이 과거 20여년 동안 저성 장 하에서도 경상수지가 흑자를 보이면서...
# 308  일부 위원은 프리미엄이 금융기관에 대 · CDS ｢ ｣ 한 신용평가를 정확하게 나타...
# 309  일부 위원은 최근 시중자금이 제 금융권의 , 2 ｢ ｣ 실적배당상품에서 은행의 정기...
# 314  일부 위원은 미국의 재정지출 확대, 보호무 역주의 강화 등으로 미 연준의 금리인상 ...
# 318  일부 위원은 지난달 연평도 포격 사태 · ｢ ｣ 에도 불구하고 스왑레이트 상승으로 ...
#
# [145 rows x 3 columns]

# %%
minutes.sort_values(by=['date'])
# Out:
#                                      title        date  \
# 318     금융통화위원회 의사록(2005년도 제14차)(2005.7.7)  2005.08.23
# 314   금융통화위원회 의사록(2005년도 제21차)(2005.10.11)  2005.11.29
# 309     금융통화위원회 의사록(2006년도 제2차)(2006.1.12)  2006.02.28
# 308     금융통화위원회 의사록(2006년도 제3차)(2006.1.26)  2006.03.14
# 307      금융통화위원회 의사록(2006년도 제4차)(2006.2.9)  2006.03.28
# ..                                     ...         ...
# 23   금융통화위원회 의사록(2019년도 제22차)(2019.11.29.)  2019.12.17
# 21   금융통화위원회 의사록(2019년도 제24차)(2019.12.26.)  2020.01.10
# 20     금융통화위원회 의사록(2020년도 제1차)(2020.1.17.)  2020.02.04
# 5     금융통화위원회 의사록(2020년도 제20차)(2020.09.10)  2020.09.29
# 1     금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
#
#                                                  의사록분석
# 318  일부 위원은 지난달 연평도 포격 사태 · ｢ ｣ 에도 불구하고 스왑레이트 상승으로 ...
# 314  일부 위원은 미국의 재정지출 확대, 보호무 역주의 강화 등으로 미 연준의 금리인상 ...
# 309  일부 위원은 최근 시중자금이 제 금융권의 , 2 ｢ ｣ 실적배당상품에서 은행의 정기...
# 308  일부 위원은 프리미엄이 금융기관에 대 · CDS ｢ ｣ 한 신용평가를 정확하게 나타...
# 307  일부 위원은 일본이 과거 20여년 동안 저성 장 하에서도 경상수지가 흑자를 보이면서...
# ..                                                 ...
# 23   일부 위원은 자본유입에 대해서는 관대 한 반면 자본유출에 대해서는 비교적 엄격한 경...
# 21   일부 위원은 2002년부터 거의 예외 없 이 연초에는 원화의 강세 현상이 나타나 왔...
# 20   일부 위원은 외화유동성 사정을 분석 , ｢ ․ ｣ 함에 있어서 유동외채비율이 중요한...
# 5    일부 위원은 최근 국제금융시장에서 국제신 · ｢ ｣ 용평가사들이 선진국의 국가신용등...
# 1    일부 위원은 최근 국제금융시장에서 금융기 , ｢ ｣ 관간 거래상대방 위험이 증대되면...
#
# [145 rows x 3 columns]

# %%
minutes=minutes.sort_values(by=['date'])
minutes= minutes.reset_index(drop=True)
minutes.to_csv('의사록분석 마지막 수정본.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-192ec61b1967> in <module>
# ----> 1 minutes=minutes.sort_values(by=['date'])
#       2 minutes= minutes.reset_index(drop=True)
#       3 minutes.to_csv('의사록분석 마지막 수정본.csv')
#
# NameError: name 'minutes' is not defined

# %%
minutes.replace('','Nan')
minutes.dropna()
minutes.to_csv('의사록분석 수정본.csv')

# %%
import pandas as pd
minutes= pd.read_csv('의사록분석.csv', header=None, encoding='utf8')

# %%
print(minutes.columns)
minutes.columns=['index','title','date','의사록분석']
# Out:
# Index(['index', 'title', 'date', '의사록분석'], dtype='object')

# %%
minutes
# Out:
#      index                                  title        date  \
# 0      NaN                                  title        date
# 1      0.0   금융통화위원회 의사록(2020년도 제26차)(2020.12.10)  2020.12.29
# 2      1.0   금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
# 3      2.0   금융통화위원회 의사록(2020년도 제23차)(2020.10.29)  2020.11.17
# 4      3.0  금융통화위원회 의사록(2020년도 제22차)(2020.10.14)   2020.11.03
# ..     ...                                    ...         ...
# 324  323.0     금융통화위원회 의사록(2005년도 제7차)(2005.3.24)  2005.05.20
# 325  324.0     금융통화위원회 의사록(2005년도 제6차)(2005.3.10)  2005.05.13
# 326  325.0     금융통화위원회 의사록(2005년도 제2차)(2005.1.13)  2005.05.12
# 327  326.0     금융통화위원회 의사록(2005년도 제4차)(2005.2.15)  2005.05.12
# 328  327.0      금융통화위원회 의사록(2005년도 제1차)(2005.1.6)  2005.04.15
#
#                                                  의사록분석
# 0                                                의사록분석
# 1    (['Economic Situation', 'Foreign Currency', 'F...
# 2    (['Economic Situation', 'Foreign Currency', 'F...
# 3    (['Economic Situation', 'Foreign Currency', 'F...
# 4    (['Economic Situation', 'Foreign Currency', 'F...
# ..                                                 ...
# 324  (['Economic Situation', 'Foreign Currency', 'F...
# 325  (['Economic Situation', 'Foreign Currency', 'F...
# 326  (['Economic Situation', 'Foreign Currency', 'F...
# 327  (['Economic Situation', 'Foreign Currency', 'F...
# 328  (['Economic Situation', 'Foreign Currency', 'F...
#
# [329 rows x 4 columns]

# %%
for i in range(328):
    if (preprocess_minutes(minutes['의사록분석'][i])[1][1:4][0] == []) == True:
        pass
    else:
        minutes['의사록분석'][i] = preprocess_minutes(minutes['의사록분석'][i])[1][1:3]
    print('완료'+str(i))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-2ad271523848> in <module>
#       1 for i in range(328):
# ----> 2     if (preprocess_minutes(minutes['의사록분석'][i])[1][1:4][0] == []) == True:
#       3         pass
#       4     else:
#       5         minutes['의사록분석'][i] = preprocess_minutes(minutes['의사록분석'][i])[1][1:3]
#
# IndexError: list index out of range

# %%
minutes.to_csv('의사록분석섹션분리.csv')

# %%
df2reset_index()
# Out:
#      index                                  title        date  \
# 0      NaN                                  title        date
# 1      0.0   금융통화위원회 의사록(2020년도 제26차)(2020.12.10)  2020.12.29
# 2      1.0   금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
# 3      2.0   금융통화위원회 의사록(2020년도 제23차)(2020.10.29)  2020.11.17
# 4      3.0  금융통화위원회 의사록(2020년도 제22차)(2020.10.14)   2020.11.03
# ..     ...                                    ...         ...
# 324  323.0     금융통화위원회 의사록(2005년도 제7차)(2005.3.24)  2005.05.20
# 325  324.0     금융통화위원회 의사록(2005년도 제6차)(2005.3.10)  2005.05.13
# 326  325.0     금융통화위원회 의사록(2005년도 제2차)(2005.1.13)  2005.05.12
# 327  326.0     금융통화위원회 의사록(2005년도 제4차)(2005.2.15)  2005.05.12
# 328  327.0      금융통화위원회 의사록(2005년도 제1차)(2005.1.6)  2005.04.15
#
#                                                  의사록분석
# 0                                                의사록분석
# 1    (['Economic Situation', 'Foreign Currency', 'F...
# 2    (['Economic Situation', 'Foreign Currency', 'F...
# 3    (['Economic Situation', 'Foreign Currency', 'F...
# 4    (['Economic Situation', 'Foreign Currency', 'F...
# ..                                                 ...
# 324  (['Economic Situation', 'Foreign Currency', 'F...
# 325  (['Economic Situation', 'Foreign Currency', 'F...
# 326  (['Economic Situation', 'Foreign Currency', 'F...
# 327  (['Economic Situation', 'Foreign Currency', 'F...
# 328  (['Economic Situation', 'Foreign Currency', 'F...
#
# [329 rows x 4 columns]

# %%
minutes
# Out:
#                                      title        date  \
# 0       금융통화위원회 의사록(2005년도 제14차)(2005.7.7)  2005.08.23
# 1     금융통화위원회 의사록(2005년도 제21차)(2005.10.11)  2005.11.29
# 2       금융통화위원회 의사록(2006년도 제2차)(2006.1.12)  2006.02.28
# 3       금융통화위원회 의사록(2006년도 제3차)(2006.1.26)  2006.03.14
# 4        금융통화위원회 의사록(2006년도 제4차)(2006.2.9)  2006.03.28
# ..                                     ...         ...
# 140  금융통화위원회 의사록(2019년도 제22차)(2019.11.29.)  2019.12.17
# 141  금융통화위원회 의사록(2019년도 제24차)(2019.12.26.)  2020.01.10
# 142    금융통화위원회 의사록(2020년도 제1차)(2020.1.17.)  2020.02.04
# 143   금융통화위원회 의사록(2020년도 제20차)(2020.09.10)  2020.09.29
# 144   금융통화위원회 의사록(2020년도 제25차)(2020.11.26)  2020.12.15
#
#                                                  의사록분석
# 0    일부 위원은 지난달 연평도 포격 사태 · ｢ ｣ 에도 불구하고 스왑레이트 상승으로 ...
# 1    일부 위원은 미국의 재정지출 확대, 보호무 역주의 강화 등으로 미 연준의 금리인상 ...
# 2    일부 위원은 최근 시중자금이 제 금융권의 , 2 ｢ ｣ 실적배당상품에서 은행의 정기...
# 3    일부 위원은 프리미엄이 금융기관에 대 · CDS ｢ ｣ 한 신용평가를 정확하게 나타...
# 4    일부 위원은 일본이 과거 20여년 동안 저성 장 하에서도 경상수지가 흑자를 보이면서...
# ..                                                 ...
# 140  일부 위원은 자본유입에 대해서는 관대 한 반면 자본유출에 대해서는 비교적 엄격한 경...
# 141  일부 위원은 2002년부터 거의 예외 없 이 연초에는 원화의 강세 현상이 나타나 왔...
# 142  일부 위원은 외화유동성 사정을 분석 , ｢ ․ ｣ 함에 있어서 유동외채비율이 중요한...
# 143  일부 위원은 최근 국제금융시장에서 국제신 · ｢ ｣ 용평가사들이 선진국의 국가신용등...
# 144  일부 위원은 최근 국제금융시장에서 금융기 , ｢ ｣ 관간 거래상대방 위험이 증대되면...
#
# [145 rows x 3 columns]
