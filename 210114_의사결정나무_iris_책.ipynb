# %%
# iris 데이터셋 준비
from sklearn.datasets import load_iris
iris = load_iris()
# 특징행렬(데이터)과 대상 벡터(레이블) 만들기
X = iris.data[:, 2:]
y = iris.target

from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=2)

tree.fit(X, y)

# export_graphviz함수에 tree모델 지정 
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file= "iris.dot",
                feature_names=iris.feature_names[2:], 
                class_names=iris.target_names,   # 분류
                rounded=True, 
                filled=True, # 색상
                impurity=True) # gini계수 출력
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-00113a267787> in <module>
#      13 # export_graphviz함수에 tree모델 지정
#      14 from sklearn.tree import export_graphviz
# ---> 15 export_graphviz(tree, out_file= "iris.dot",
#      16                 feature_names=iris.feature_names[2:],
#      17                 class_names=iris.target_names,   # 분류
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     767     try:
#     768         if isinstance(out_file, str):
# --> 769             out_file = open(out_file, "w", encoding="utf-8")
#     770             own_file = True
#     771
#
# OSError: [Errno 22] Invalid argument: 'iris.dot'

# %%
import graphviz

with open("iris.dot") as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-e2ff2a2ad6b8> in <module>
#       1 import graphviz
#       2
# ----> 3 with open("iris.dot") as f:
#       4     dot_graph = f.read()
#       5
#
# OSError: [Errno 22] Invalid argument: 'iris.dot'
